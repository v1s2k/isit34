# %%
import pandas as pd
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt


data = pd.read_csv('hepatitis.csv')


data = data.dropna()
numeric_features = data.select_dtypes(include=[np.number])
print(numeric_features)
# Отделите признаки от меток классов
X = numeric_features.drop('age', axis=1)
#  пропущенные значения
X = X.fillna(X.mean())

# Применение алгоритма t-sne
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X)


plt.scatter(X_tsne [:, 0], X_tsne [:, 1],c=data['age'] ,cmap='viridis')
plt.title('t-SNE Визуализация')
plt.xlabel('Параметр 1')
plt.ylabel('Параметр 2')
plt.colorbar()
plt.show()
# Out:
#      age  bilirubin  alk_phosphate   sgot  albumin  protime
# 5     34        0.9           95.0   28.0      4.0     75.0
# 10    39        1.3           78.0   30.0      4.4     85.0
# 11    32        1.0           59.0  249.0      3.7     54.0
# 12    41        0.9           81.0   60.0      3.9     52.0
# 13    30        2.2           57.0  144.0      4.9     78.0
# ..   ...        ...            ...    ...      ...      ...
# 139   45        1.3           85.0   44.0      4.2     85.0
# 143   49        1.4           85.0   70.0      3.5     35.0
# 145   31        1.2           75.0  173.0      4.2     54.0
# 153   53        1.5           81.0   19.0      4.1     48.0
# 154   43        1.2          100.0   19.0      3.1     42.0
#
# [80 rows x 6 columns]
